# %%
i=12
r=20
v=i*r
print(v)
# Out:
# 240

# %%
r1=float(input("r1= ")) 

r2=float(input("r2= ")) 

rp=1/(1/r1)+(1/r2) 

print(rp)
# Out:
# r1=  20
# r2=  12
# 20.083333333333332

# %%
r1=float(input("r1= ")) 

r2=float(input("r2= ")) 

rs=r1+r2 

print(rs)
# Out:
# r1=  20
# r2=  10
# 30.0
